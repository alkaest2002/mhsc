# %%
from enum import Enum

import numpy as np
import pandas as pd

# %%
Gender = Enum("Gender", ["M", "F"])
Age = Enum("Age", ["17-30", "31-40", "41-50", "51-60", ">60" ])
Job = Enum("Job", ["Pilot", "Applicant", "Crew", "ATC", "Other"])
Status = Enum("Status", ["Military", "Civilian", "Other"])

# %%
subject_id =     223
subject_gender = "M"
subject_age =    "41-50"
subject_job =    "Pilot"
subject_status = "Military"

#################################

mhsc_01_01 = 0
mhsc_01_02 = 0
mhsc_01_03 = 0
mhsc_01_04 = 0
mhsc_01_05 = 0
mhsc_01_06 = 0
mhsc_01_07 = 0
mhsc_01_08 = 0
mhsc_01_09 = 0
mhsc_01_10 = 0
#-----------------
mhsc_02_01 = 1
mhsc_02_02 = 1
mhsc_02_03 = 0
mhsc_02_04 = 0
mhsc_02_05 = 0
#-----------------
mhsc_03_01 = 0
mhsc_03_02 = 0
mhsc_03_03 = 0
mhsc_03_04 = 0
mhsc_03_05 = 0
#-----------------
mhsc_04_01 = 6

#################################

enac_self_assessment =      6
enac_self_report_atypical = 0
enac_interview_atypical =   0
enac_need_referral =        0


row = dict(
    bio_id=subject_id,
    bio_gender=Gender[subject_gender].value,
    bio_age=Age[subject_age].value,
    bio_job=Job[subject_job].value,
    bio_status=Status[subject_status].value,
    enac_self_assessment=enac_self_assessment,
    enac_self_report_atypical=enac_self_report_atypical,
    enac_interview_atypical=enac_interview_atypical,
    enac_need_referral=enac_need_referral,
    mhsc_01_01=mhsc_01_01,
    mhsc_01_02=mhsc_01_02,
    mhsc_01_03=mhsc_01_03,
    mhsc_01_04=mhsc_01_04,
    mhsc_01_05=mhsc_01_05,
    mhsc_01_06=mhsc_01_06,
    mhsc_01_07=mhsc_01_07,
    mhsc_01_08=mhsc_01_08,
    mhsc_01_09=mhsc_01_09,
    mhsc_01_10=mhsc_01_10,
    mhsc_02_01=mhsc_02_01,
    mhsc_02_02=mhsc_02_02,
    mhsc_02_03=mhsc_02_03,
    mhsc_02_04=mhsc_02_04,
    mhsc_02_05=mhsc_02_05,
    mhsc_03_01=mhsc_03_01,
    mhsc_03_02=mhsc_03_02,
    mhsc_03_03=mhsc_03_03,
    mhsc_03_04=mhsc_03_04,
    mhsc_03_05=mhsc_03_05,
    mhsc_04_01=mhsc_04_01,
)

if True:
    (
        pd.DataFrame(
            row, 
            index=[subject_id],
        )
        .to_csv("./mhsc_data.csv", index=False,  mode='a', header=False)
    )
